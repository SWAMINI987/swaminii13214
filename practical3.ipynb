# %%
import pandas as pd
df=pd.read_csv("ecomerce.csv")
df
# Out:
#         user_id  age  gender  country urban_rural  income_level  \
# 0             1   56  Female  Germany    Suburban         90860
# 1             2   69    Male    Japan    Suburban         35423
# 2             3   46  Female    India       Urban         21467
# 3             4   32    Male   Canada       Urban         41770
# 4             5   60  Female    Japan       Urban        183882
# ...         ...  ...     ...      ...         ...           ...
# 145909   145910   74  Female   Canada       Urban        156002
# 145910   145911   64    Male   Canada    Suburban         20492
# 145911   145912   19  Female   France    Suburban         18738
# 145912   145913   53    Male   Canada       Rural         95892
# 145913   145914   46  Female       UK       Urban        126519
#
#        employment_status   education_level relationship_status  has_children  \
# 0          Self-employed  Associate Degree              Single             0
# ...

# %%
df.describe()
# Out:
#              user_id            age   income_level   has_children  \
# count  145914.000000  145914.000000  145914.000000  145914.000000
# mean    72957.500000      49.023329  105161.305968       0.400510
# std     42121.887927      18.158512   54900.977280       0.490003
# min         1.000000      18.000000   10000.000000       0.000000
# 25%     36479.250000      33.000000   57607.000000       0.000000
# 50%     72957.500000      49.000000  105226.000000       0.000000
# 75%    109435.750000      65.000000  152921.750000       1.000000
# max    145914.000000      80.000000  199999.000000       1.000000
#
#        household_size  weekly_purchases  monthly_spend  cart_abandonment_rate  \
# count   145914.000000     145914.000000  145914.000000          145914.000000
# mean         5.504468          9.988603    2502.998102              40.243787
# std          2.875569          6.055555    1447.001489              25.462565
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=145914, step=1)

# %%
df.columns
# Out:
# Index(['user_id', 'age', 'gender', 'country', 'urban_rural', 'income_level',
#        'employment_status', 'education_level', 'relationship_status',
#        'has_children', 'household_size', 'occupation', 'ethnicity',
#        'language_preference', 'device_type', 'weekly_purchases',
#        'monthly_spend', 'cart_abandonment_rate', 'review_writing_frequency',
#        'average_order_value', 'preferred_payment_method',
#        'coupon_usage_frequency', 'loyalty_program_member', 'referral_count',
#        'product_category_preference', 'shopping_time_of_day',
#        'weekend_shopper', 'impulse_purchases_per_month', 'browse_to_buy_ratio',
#        'return_frequency', 'budgeting_style', 'brand_loyalty_score',
#        'impulse_buying_score', 'environmental_consciousness',
#        'health_conscious_shopping', 'travel_frequency', 'hobby_count',
#        'social_media_influence_score', 'reading_habits', 'exercise_frequency',
# ...

# %%
df.shape
# Out:
# (145914, 60)

# %%
df.dtypes
# Out:
# user_id                              int64
# age                                  int64
# gender                              object
# country                             object
# urban_rural                         object
# income_level                         int64
# employment_status                   object
# education_level                     object
# relationship_status                 object
# has_children                         int64
# household_size                       int64
# occupation                          object
# ethnicity                           object
# language_preference                 object
# device_type                         object
# weekly_purchases                     int64
# monthly_spend                        int64
# cart_abandonment_rate                int64
# review_writing_frequency             int64
# average_order_value                float64
# preferred_payment_method            object
# coupon_usage_frequency             float64
# ...

# %%
df.columns.values
# Out:
# array(['user_id', 'age', 'gender', 'country', 'urban_rural',
#        'income_level', 'employment_status', 'education_level',
#        'relationship_status', 'has_children', 'household_size',
#        'occupation', 'ethnicity', 'language_preference', 'device_type',
#        'weekly_purchases', 'monthly_spend', 'cart_abandonment_rate',
#        'review_writing_frequency', 'average_order_value',
#        'preferred_payment_method', 'coupon_usage_frequency',
#        'loyalty_program_member', 'referral_count',
#        'product_category_preference', 'shopping_time_of_day',
#        'weekend_shopper', 'impulse_purchases_per_month',
#        'browse_to_buy_ratio', 'return_frequency', 'budgeting_style',
#        'brand_loyalty_score', 'impulse_buying_score',
#        'environmental_consciousness', 'health_conscious_shopping',
#        'travel_frequency', 'hobby_count', 'social_media_influence_score',
#        'reading_habits', 'exercise_frequency',
# ...

# %%
df.iloc[100]
# Out:
# user_id                                          101
# age                                               61
# gender                                        Female
# country                                        China
# urban_rural                                 Suburban
# income_level                                   41317
# employment_status                         Unemployed
# education_level                     Associate Degree
# relationship_status                In a relationship
# has_children                                       1
# household_size                                     4
# occupation                                        IT
# ethnicity                           African American
# language_preference                            Hindi
# device_type                                   Mobile
# weekly_purchases                                  12
# monthly_spend                                   1418
# cart_abandonment_rate                             43
# ...

# %%
df.columns.names
# Out:
# FrozenList([None])

# %%
df.iloc[:100,2:5]
# Out:
#     gender  country urban_rural
# 0   Female  Germany    Suburban
# 1     Male    Japan    Suburban
# 2   Female    India       Urban
# 3     Male   Canada       Urban
# 4   Female    Japan       Urban
# ..     ...      ...         ...
# 95  Female       UK       Rural
# 96  Female      USA    Suburban
# 97  Female      USA    Suburban
# 98    Male    India    Suburban
# 99  Female    Japan       Urban
#
# [100 rows x 3 columns]

# %%
df.iloc[:5,1:4]
# Out:
#    age  gender  country
# 0   56  Female  Germany
# 1   69    Male    Japan
# 2   46  Female    India
# 3   32    Male   Canada
# 4   60  Female    Japan

# %%
df.CreditScore.min()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-2072152b5fb9> in ?()
# ----> 1 df.CreditScore.min()
#
# /lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'CreditScore'

# %%
df.age.min()
# Out:
# np.int64(18)

# %%
df.head[5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df.head[5]
#
# TypeError: 'method' object is not subscriptable
