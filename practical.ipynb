# %%
import pandas as pd;

# %%
df=pd.read_csv("STUDENT PERFORMANCE1.CSV")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   math score       24 non-null     float64
#  1   reading score    25 non-null     float64
#  2   writing score    25 non-null     float64
#  3   placement score  28 non-null     float64
#  4   club join year   24 non-null     float64
#  5   placement offer  29 non-null     float64
# dtypes: float64(6)
# memory usage: 1.8 KB

# %%
df.isnull().sum()
# Out:
# math score         13
# reading score      12
# writing score      12
# placement score     9
# club join year     13
# placement offer     8
# dtype: int64

# %%
df['math score'].max()
# Out:
# np.float64(80.0)

# %%
df.describe()
# Out:
#        math score  reading score  writing score  placement score  \
# count   24.000000      25.000000      25.000000        28.000000
# mean    60.500000     793.200000      60.440000        84.821429
# std     26.542828    2485.233959      21.966034        21.842964
# min      1.000000       1.000000       0.000000         1.000000
# 25%     63.750000      82.000000      62.000000        85.250000
# 50%     70.500000      82.000000      67.000000        90.000000
# 75%     74.250000      87.000000      71.000000        96.250000
# max     80.000000   10000.000000      80.000000       100.000000
#
#        club join year  placement offer
# count       24.000000        29.000000
# mean      2019.750000         2.724138
# std          1.032094         0.454859
# min       2018.000000         2.000000
# 25%       2019.000000         2.000000
# 50%       2020.000000         3.000000
# 75%       2020.250000         3.000000
# max       2021.000000         3.000000

# %%
df.isnull().sum
# Out:
# <bound method DataFrame.sum of     math score  reading score  writing score  placement score  club join year  \
# 0        False          False          False            False           False
# 1        False          False          False            False           False
# 2        False          False          False            False           False
# 3        False          False          False            False           False
# 4        False           True          False            False           False
# 5        False           True          False            False            True
# 6        False           True          False            False            True
# 7        False           True          False            False            True
# 8        False          False          False            False            True
# 9        False          False          False            False            True
# 10       False          False          False            False           False
# ...

# %%
x=df['math score'].mean()

# %%
df['math score'].fillna(x)
# Out:
# 0     63.0
# 1     65.0
# 2     70.0
# 3     77.0
# 4      1.0
# 5     73.0
# 6      5.0
# 7     74.0
# 8     72.0
# 9     68.0
# 10     2.0
# 11     6.0
# 12    62.0
# 13    80.0
# 14    60.5
# 15    60.5
# 16    60.5
# 17    60.5
# 18    60.5
# 19    80.0
# 20    71.0
# 21    75.0
# 22    74.0
# 23    69.0
# 24    80.0
# 25    77.0
# 26    74.0
# 27    64.0
# 28    70.0
# 29    60.5
# 30    60.5
# 31    60.5
# 32    60.5
# 33    60.5
# 34    60.5
# 35    60.5
# 36    60.5
# Name: math score, dtype: float64

# %%
df['math score'].fillna(x, inplace=True)
# Out:
# <ipython-input-19-e6c9b27df9af>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['math score'].fillna(x, inplace=True)

# %%
df.iloc[5:6,1:2].fillna(56,inplace=True)
# Out:
# <ipython-input-20-fc19d36fda0f>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.iloc[5:6,1:2].fillna(56,inplace=True)

# %%
df['placement offer'].fillna(15,inplace=True)
# Out:
# <ipython-input-26-eaca1b43cfd3>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['placement offer'].fillna(15,inplace=True)

# %%
df

# %%
df['club join'].mode()

# %%
df

# %%
df.isnull().sum().sum()

# %%
df.columns

# %%
df.boxplot(column='math score')
# Out:
# <Axes: >

# %%
df.boxplot('math score')
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
plt.show()

# %%
fig,ax=plt.subplots(figsize=(18,10))

# %%
df['placement offer']
# Out:
# 0      3.0
# 1      2.0
# 2      3.0
# 3      3.0
# 4      3.0
# 5      3.0
# 6      2.0
# 7      2.0
# 8      3.0
# 9      3.0
# 10     3.0
# 11     2.0
# 12     3.0
# 13     3.0
# 14     3.0
# 15     3.0
# 16     3.0
# 17     2.0
# 18     3.0
# 19     3.0
# 20     3.0
# 21     3.0
# 22     2.0
# 23     2.0
# 24     3.0
# 25     3.0
# 26     2.0
# 27     3.0
# 28     3.0
# 29    15.0
# 30    15.0
# 31    15.0
# 32    15.0
# 33    15.0
# 34    15.0
# 35    15.0
# 36    15.0
# Name: placement offer, dtype: float64
