# %%
//Roll No :13214
div : B
problem statement :1text analysis operatiion using natural language toolkit.
                   2text analysis model using TF-IDF

# %%
pip install nltk

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
text = "Tokenization is the first step in text analytics. It breaks text into words or sentences."

# %%
from nltk.tokenize import sent_tokenize

sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['Tokenization is the first step in text analytics.', 'It breaks text into words or sentences.']

# %%
from nltk.tokenize import sent_tokenize

text = "Tokenization is the first step in text analytics. It breaks text into words or sentences."

sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['Tokenization is the first step in text analytics.', 'It breaks text into words or sentences.']

# %%
from nltk.tokenize import word_tokenize

words = word_tokenize(text)
print(words)
# Out:
# ['Tokenization', 'is', 'the', 'first', 'step', 'in', 'text', 'analytics', '.', 'It', 'breaks', 'text', 'into', 'words', 'or', 'sentences', '.']

# %%
import string

words_no_punct = [w for w in words if w not in string.punctuation]
print(words_no_punct)
# Out:
# ['Tokenization', 'is', 'the', 'first', 'step', 'in', 'text', 'analytics', 'It', 'breaks', 'text', 'into', 'words', 'or', 'sentences']

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

filtered_words = [w for w in words_no_punct if w.lower() not in stop_words]
print(filtered_words)
# Out:
# ['Tokenization', 'first', 'step', 'text', 'analytics', 'breaks', 'text', 'words', 'sentences']

# %%
from nltk.stem import PorterStemmer

ps = PorterStemmer()

stemmed_words = [ps.stem(w) for w in filtered_words]
print(stemmed_words)
# Out:
# ['token', 'first', 'step', 'text', 'analyt', 'break', 'text', 'word', 'sentenc']

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

lemmatized_words = [lemmatizer.lemmatize(w) for w in filtered_words]
print(lemmatized_words)
# Out:
# ['Tokenization', 'first', 'step', 'text', 'analytics', 'break', 'text', 'word', 'sentence']

# %%
from nltk import pos_tag

pos_tags = pos_tag(words)
print(pos_tags)
# Out:
# [('Tokenization', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('first', 'JJ'), ('step', 'NN'), ('in', 'IN'), ('text', 'JJ'), ('analytics', 'NNS'), ('.', '.'), ('It', 'PRP'), ('breaks', 'VBZ'), ('text', 'NN'), ('into', 'IN'), ('words', 'NNS'), ('or', 'CC'), ('sentences', 'NNS'), ('.', '.')]
