# %%
import pandas as pd

# %%
df=pd.read_csv("STUDENT PERFORMANCE.CSV")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   math score       29 non-null     float64
#  1   reading score    29 non-null     float64
#  2   writing score    29 non-null     float64
#  3   placement score  32 non-null     float64
#  4   club join year   29 non-null     float64
#  5   placement offer  29 non-null     float64
# dtypes: float64(6)
# memory usage: 1.8 KB

# %%
df.fillna(13)
# Out:
#     math score  reading score  writing score  placement score  club join year  \
# 0         63.0           94.0           79.0             91.0          2021.0
# 1         65.0           87.0           75.0             78.0          2020.0
# 2         70.0           90.0           67.0             87.0          2021.0
# 3         77.0           90.0           69.0             99.0          2021.0
# 4         63.0           78.0           61.0             98.0          2019.0
# 5         73.0           76.0           66.0             92.0          2018.0
# 6         71.0           85.0           67.0             75.0          2020.0
# 7         74.0           83.0           78.0             81.0          2021.0
# 8         72.0           87.0           64.0             86.0          2021.0
# 9         68.0           81.0           62.0             86.0          2019.0
# 10        80.0           82.0           71.0             93.0          2018.0
# ...

# %%
df.min
# Out:
# <bound method DataFrame.min of     math score  reading score  writing score  placement score  club join year  \
# 0         63.0           94.0           79.0             91.0          2021.0
# 1         65.0           87.0           75.0             78.0          2020.0
# 2         70.0           90.0           67.0             87.0          2021.0
# 3         77.0           90.0           69.0             99.0          2021.0
# 4         63.0           78.0           61.0             98.0          2019.0
# 5         73.0           76.0           66.0             92.0          2018.0
# 6         71.0           85.0           67.0             75.0          2020.0
# 7         74.0           83.0           78.0             81.0          2021.0
# 8         72.0           87.0           64.0             86.0          2021.0
# 9         68.0           81.0           62.0             86.0          2019.0
# 10        80.0           82.0           71.0             93.0          2018.0
# ...

# %%
df.tail(7)
# Out:
#     math score  reading score  writing score  placement score  club join year  \
# 30         NaN            NaN            NaN              NaN             NaN
# 31         NaN            NaN            NaN              NaN             NaN
# 32         NaN            NaN            NaN              NaN             NaN
# 33         NaN            NaN            NaN              NaN             NaN
# 34         NaN            NaN            NaN             94.0             NaN
# 35         NaN            NaN            NaN             95.0             NaN
# 36         NaN            NaN            NaN             92.0             NaN
#
#     placement offer
# 30              NaN
# 31              NaN
# 32              NaN
# 33              NaN
# 34              NaN
# 35              NaN
# 36              NaN

# %%
df.tail(8)
# Out:
#     math score  reading score  writing score  placement score  club join year  \
# 29         NaN            NaN            NaN              NaN             NaN
# 30         NaN            NaN            NaN              NaN             NaN
# 31         NaN            NaN            NaN              NaN             NaN
# 32         NaN            NaN            NaN              NaN             NaN
# 33         NaN            NaN            NaN              NaN             NaN
# 34         NaN            NaN            NaN             94.0             NaN
# 35         NaN            NaN            NaN             95.0             NaN
# 36         NaN            NaN            NaN             92.0             NaN
#
#     placement offer
# 29              NaN
# 30              NaN
# 31              NaN
# 32              NaN
# 33              NaN
# 34              NaN
# 35              NaN
# 36              NaN

# %%
df.describe()
# Out:
#        math score  reading score  writing score  placement score  \
# count   29.000000      29.000000      29.000000        32.000000
# mean    72.206897      84.758621      68.586207        90.343750
# std      5.906288       5.369591       6.161616         6.995895
# min     62.000000      76.000000      60.000000        75.000000
# 25%     69.000000      81.000000      64.000000        85.500000
# 50%     73.000000      83.000000      67.000000        91.500000
# 75%     77.000000      89.000000      71.000000        97.000000
# max     80.000000      94.000000      80.000000       100.000000
#
#        club join year  placement offer
# count       29.000000        29.000000
# mean      2019.758621         2.724138
# std          1.057462         0.454859
# min       2018.000000         2.000000
# 25%       2019.000000         2.000000
# 50%       2020.000000         3.000000
# 75%       2021.000000         3.000000
# max       2021.000000         3.000000

# %%
df
# Out:
#     math score  reading score  writing score  placement score  club join year  \
# 0         63.0           94.0           79.0             91.0          2021.0
# 1         65.0           87.0           75.0             78.0          2020.0
# 2         70.0           90.0           67.0             87.0          2021.0
# 3         77.0           90.0           69.0             99.0          2021.0
# 4         63.0           78.0           61.0             98.0          2019.0
# 5         73.0           76.0           66.0             92.0          2018.0
# 6         71.0           85.0           67.0             75.0          2020.0
# 7         74.0           83.0           78.0             81.0          2021.0
# 8         72.0           87.0           64.0             86.0          2021.0
# 9         68.0           81.0           62.0             86.0          2019.0
# 10        80.0           82.0           71.0             93.0          2018.0
# ...

# %%
df.min
# Out:
# <bound method DataFrame.min of     math score  reading score  writing score  placement score  club join year  \
# 0         63.0           94.0           79.0             91.0          2021.0
# 1         65.0           87.0           75.0             78.0          2020.0
# 2         70.0           90.0           67.0             87.0          2021.0
# 3         77.0           90.0           69.0             99.0          2021.0
# 4         63.0           78.0           61.0             98.0          2019.0
# 5         73.0           76.0           66.0             92.0          2018.0
# 6         71.0           85.0           67.0             75.0          2020.0
# 7         74.0           83.0           78.0             81.0          2021.0
# 8         72.0           87.0           64.0             86.0          2021.0
# 9         68.0           81.0           62.0             86.0          2019.0
# 10        80.0           82.0           71.0             93.0          2018.0
# ...

# %%
df.columns.values
# Out:
# array(['math score', 'reading score', 'writing score', 'placement score',
#        'club join year', 'placement offer'], dtype=object)

# %%
df.iloc[20]
# Out:
# math score           71.0
# reading score        82.0
# writing score        61.0
# placement score      98.0
# club join year     2018.0
# placement offer       3.0
# Name: 20, dtype: float64

# %%
df.iloc[:,1:4]
# Out:
#     reading score  writing score  placement score
# 0            94.0           79.0             91.0
# 1            87.0           75.0             78.0
# 2            90.0           67.0             87.0
# 3            90.0           69.0             99.0
# 4            78.0           61.0             98.0
# 5            76.0           66.0             92.0
# 6            85.0           67.0             75.0
# 7            83.0           78.0             81.0
# 8            87.0           64.0             86.0
# 9            81.0           62.0             86.0
# 10           82.0           71.0             93.0
# 11           81.0           62.0             83.0
# 12           90.0           60.0             96.0
# 13           88.0           62.0             89.0
# 14           78.0           67.0             98.0
# 15           76.0           62.0             97.0
# 16           94.0           67.0             96.0
# 17           83.0           71.0             82.0
# ...

# %%
df.math score.fillna(67)
# Out:
#   Cell In[32], line 1
#     df.math score.fillna(67)
#             ^
# SyntaxError: invalid syntax
